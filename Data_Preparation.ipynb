# %% [markdown]
# # Prepare the data for modeling by splitting into Train/validate and Test data

# %%
#Read the CSV containing 629 features
import pandas as pd

df= pd.read_csv('quora-question-pairs/final_features.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Columns: 628 entries, id to 299_y
# dtypes: float64(614), int64(14)
# memory usage: 1.9 GB

# %%
df.head()
# Out:
#    id  is_duplicate   cwc_min   cwc_max   csc_min   csc_max   ctc_min  \
# 0   0             0  0.999980  0.833319  0.999983  0.999983  0.916659
# 1   1             0  0.799984  0.399996  0.749981  0.599988  0.699993
# 2   2             0  0.399992  0.333328  0.399992  0.249997  0.399996
# 3   3             0  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   4             0  0.399992  0.199998  0.999950  0.666644  0.571420
#
#     ctc_max  last_word_eq  first_word_eq  ...      290_y     291_y      292_y  \
# 0  0.785709           0.0            1.0  ... -17.810438  7.231024   1.531186
# 1  0.466664           0.0            1.0  ...  23.015827  3.435464  -5.169600
# 2  0.285712           0.0            1.0  ... -24.310109 -1.216773  11.909693
# 3  0.000000           0.0            0.0  ...  -5.435584  1.672591  -0.863278
# 4  0.307690           0.0            1.0  ... -10.407441 -8.444207 -14.450059
#
# ...

# %%
df.shape
# Out:
# (404290, 627)

# %%
df=df.drop('id', axis=1)
#Checking whether there are any rows with null values
nan_rows = df[df.isnull().any(1)]
df = df.dropna( how='any',
                    subset=['is_duplicate'])

# %%
df.head()
# Out:
#    is_duplicate   cwc_min   cwc_max   csc_min   csc_max   ctc_min   ctc_max  \
# 0             0  0.999980  0.833319  0.999983  0.999983  0.916659  0.785709
# 1             0  0.799984  0.399996  0.749981  0.599988  0.699993  0.466664
# 2             0  0.399992  0.333328  0.399992  0.249997  0.399996  0.285712
# 3             0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4             0  0.399992  0.199998  0.999950  0.666644  0.571420  0.307690
#
#    last_word_eq  first_word_eq  abs_len_diff  ...      290_y     291_y  \
# 0           0.0            1.0           2.0  ... -17.810438  7.231024
# 1           0.0            1.0           5.0  ...  23.015827  3.435464
# 2           0.0            1.0           4.0  ... -24.310109 -1.216773
# 3           0.0            0.0           2.0  ...  -5.435584  1.672591
# 4           0.0            1.0           6.0  ... -10.407441 -8.444207
#
#        292_y      293_y      294_y      295_y      296_y      297_y  \
# ...

# %%
df.shape
# Out:
# (404290, 627)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Columns: 627 entries, is_duplicate to 299_y
# dtypes: float64(614), int64(13)
# memory usage: 1.9 GB

# %%
print(df)
# Out:
#             id  is_duplicate   cwc_min   cwc_max   csc_min   csc_max  \
# 0            0             0  0.999980  0.833319  0.999983  0.999983
# 1            1             0  0.799984  0.399996  0.749981  0.599988
# 2            2             0  0.399992  0.333328  0.399992  0.249997
# 3            3             0  0.000000  0.000000  0.000000  0.000000
# 4            4             0  0.399992  0.199998  0.999950  0.666644
# ...        ...           ...       ...       ...       ...       ...
# 404285  404285             0  0.857131  0.857131  0.999980  0.833319
# 404286  404286             1  0.666644  0.666644  0.599988  0.599988
# 404287  404287             0  0.999900  0.499975  0.999950  0.666644
# 404288  404288             0  0.000000  0.000000  0.124998  0.099999
# 404289  404289             0  0.999967  0.999967  0.999980  0.714276
#
#          ctc_min   ctc_max  last_word_eq  first_word_eq  ...      290_y  \
# ...

# %%
#Split the dataset into 80:20 using stratify
from sklearn.model_selection import train_test_split
x = df
y = df['is_duplicate']
x_train, x_test, y_train,y_test = train_test_split(x, y, test_size = 0.2,  stratify = y)

# %%
print(x_train)
# Out:
#             id  is_duplicate   cwc_min   cwc_max   csc_min   csc_max  \
# 53800    53800             0  0.199996  0.199996  0.799984  0.666656
# 249101  249101             1  0.499992  0.374995  0.333322  0.142855
# 378421  378421             0  0.714276  0.416663  0.666656  0.444440
# 337308  337308             0  0.749981  0.499992  0.749981  0.499992
# 159637  159637             1  0.599988  0.499992  0.499975  0.249994
# ...        ...           ...       ...       ...       ...       ...
# 62266    62266             0  0.666644  0.666644  0.999900  0.999900
# 124500  124500             1  0.999950  0.666644  0.499992  0.499992
# 139427  139427             1  0.749981  0.749981  0.399992  0.333328
# 103391  103391             1  0.999975  0.799984  0.999983  0.857131
# 282862  282862             1  0.714276  0.454541  0.749981  0.428565
#
#          ctc_min   ctc_max  last_word_eq  first_word_eq  ...      290_y  \
# ...

# %%
print(x_test)
# Out:
#             id  is_duplicate   cwc_min   cwc_max   csc_min   csc_max  \
# 351104  351104             0  0.499988  0.399992  0.571420  0.444440
# 342101  342101             0  0.428565  0.428565  0.249994  0.142855
# 380686  380686             0  0.999950  0.999950  0.999983  0.749991
# 11880    11880             1  0.999950  0.999950  0.333322  0.333322
# 381325  381325             0  0.666644  0.666644  0.999975  0.999975
# ...        ...           ...       ...       ...       ...       ...
# 190705  190705             0  0.499975  0.333322  0.999950  0.499988
# 286302  286302             0  0.666644  0.166665  0.999900  0.199996
# 107435  107435             0  0.333322  0.199996  0.000000  0.000000
# 207212  207212             1  0.599988  0.599988  0.799984  0.799984
# 269662  269662             1  0.499975  0.499975  0.249994  0.199996
#
#          ctc_min   ctc_max  last_word_eq  first_word_eq  ...      290_y  \
# ...

# %%
df_train = pd.DataFrame(x_train)
df_test = pd.DataFrame(x_test)

# %%
#Save the Training data into Final_Training_V01.csv
df_train.to_csv('Final_Training_V01.csv', index=False , encoding="utf-8")

# %%
#Save the Training data into Final_Test_V01.csv
df_test.to_csv('Final_Test_V01.csv', index=False , encoding="utf-8")
